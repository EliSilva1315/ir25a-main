# %% [markdown]
# # Ejercicio 12 : Asistente RAG Recipes
#
# ## Objetivo de la práctica
#
# Construir un asistente que:
#
# 1. Recibe una pregunta del usuario
# 2. Recupera texto relevante de un corpus (ej. libro de Baeza-Yates)
# 3. Genera una respuesta basada en los documentos encontrados

# %% [markdown]
# ## Parte 0: Librerías necesarias
# - openai
# - faiss-cpu
# - sentence-transformers

# %%
import fitz  
import pandas as pd
import os
import re
import json
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
from openai import OpenAI
from openai import OpenAI

# %% [markdown]
# ## Parte 1: Carga del corpus
#
# Aquí se debe cargar el corpus con las recetas del json

# %%
import json
import pandas as pd

corpus_path = '../data/recipes_data.json'
data = []

with open(corpus_path, 'r', encoding='utf-8') as file:
    recipes = json.load(file)
    for url, recipe in recipes.items():
        title = recipe.get('title', 'Sin título')
        content = "\n".join(recipe.get('steps', []))  # Unimos los pasos como contenido
        data.append({
            'url': url,
            'title': title,
            'content': content
        })

df = pd.DataFrame(data)
df
# Out:
#                                                   url  \
# 0   https://www.allrecipes.com/recipe/93168/rotiss...
# 1   https://www.allrecipes.com/recipe/93168/rotiss...
# 2   https://www.allrecipes.com/recipe/238575/cilan...
# 3   https://www.allrecipes.com/recipe/275062/butte...
# 4   https://www.allrecipes.com/recipe/274724/grill...
# 5   https://www.allrecipes.com/recipe/14531/beer-b...
# 6   https://www.allrecipes.com/recipe/221093/good-...
# 7   https://www.allrecipes.com/recipe/264278/miso-...
# 8   https://www.allrecipes.com/recipe/258659/rosem...
# 9   https://www.allrecipes.com/recipe/222936/smoke...
# 10  https://www.allrecipes.com/recipe/228070/the-b...
# 11  https://www.allrecipes.com/recipe/214619/bbq-b...
# 12  https://www.allrecipes.com/recipe/19944/drunk-...
# 13  https://www.allrecipes.com/recipe/275044/grill...
# 14  https://www.allrecipes.com/recipe/281255/smoke...
# 15  https://www.allrecipes.com/recipe/34957/easy-b...
# 16  https://www.allrecipes.com/recipe/8998/darn-go...
# 17  https://www.allrecipes.com/recipe/214618/beer-...
#
#                              title  \
# 0               Rotisserie Chicken
# 1               Rotisserie Chicken
# 2    Cilantro-Lime Grilled Chicken
# 3      Buttermilk Barbecue Chicken
# 4     Grilled Spatchcocked Chicken
# 5                Beer Butt Chicken
# 6    Good Frickin' Paprika Chicken
# 7               Miso Honey Chicken
# 8      Rosemary Buttermilk Chicken
# 9         Smoked Beer Butt Chicken
# 10  The Best Beer Can Chicken Ever
# 11           Best Beer Can Chicken
# 12                   Drunk Chicken
# 13   Grilled Chicken Under a Brick
# 14            Smoked Whole Chicken
# 15           Easy Barbeque Chicken
# 16               Darn Good Chicken
# 17                Beer Can Chicken
#
#                                               content
# 0   Gather all ingredients. Preheat an outdoor gri...
# 1   Gather all ingredients. Preheat an outdoor gri...
# 2   Whisk cilantro, lime juice, garlic salt, and b...
# 3   Whisk buttermilk, brown sugar, cider vinegar, ...
# 4   Place salt in a large bowl or Dutch oven; add ...
# 5   Preheat an outdoor grill for low heat and ligh...
# 6   Whisk together yogurt, garlic, 3 tablespoons p...
# 7   Combine miso and honey in a bowl. Pour in rice...
# 8   Mix buttermilk, garlic, paprika, salt, and pep...
# 9   Preheat grill for medium heat and lightly oil ...
# 10  Preheat grill for medium heat. If using charco...
# 11  Soak wood chips in water for at least 1 hour.\...
# 12  Rinse and dry chicken. Remove excess fat and l...
# 13  Place the chicken, breast side down, on a cutt...
# 14  Preheat a smoker to 250 degrees F (120 degrees...
# 15  In a large glass bowl mix lemon juice, vegetab...
# 16  In a small bowl combine the warm honey, mustar...
# 17  Preheat an outdoor grill for medium-high heat,...

# %% [markdown]
# ## Parte 2: Procesamiento del Corpus
#
# Aquí se debe obtener el corpus procesado. El corpus estará formado por documentos que corresponden a las secciones (o subsecciones) de los libros. Cada documento debe indicar a qué libro corresponde, así como las páginas en las que está dentro de ese libro.
#
# Recuerden que los documentos procesados no deben contener textos o caracteres ajenos al tema del que tratan.

# %%
all_toc = []

with open(corpus_path, 'r', encoding='utf-8') as file:
    recipes = json.load(file)

    for url, recipe in recipes.items():
        title = recipe.get("title", "Sin título").strip()
        resume = recipe.get("resume", "")
        ingredients = recipe.get("ingredients", [])
        steps = recipe.get("steps", [])
        nutrition_facts = recipe.get("nutrition_facts", {})
        img_url = recipe.get("image_url", "")

        # Sección 1: Resumen
        all_toc.append({
            "receta": title,
            "nivel": 1,
            "sección": "1",
            "título": "Resumen",
            "texto": resume,
            "fuente_TOC": "JSON"
        })

        # Sección 2: Ingredientes
        ingredients_text = "\n".join(f"- {ing}" for ing in ingredients)
        all_toc.append({
            "receta": title,
            "nivel": 1,
            "sección": "2",
            "título": "Ingredientes",
            "texto": ingredients_text,
            "fuente_TOC": "JSON"
        })

        # Sección 3: Pasos
        for idx, step in enumerate(steps, 1):
            all_toc.append({
                "receta": title,
                "nivel": 2,
                "sección": f"3.{idx}",
                "título": f"Paso {idx}",
                "texto": step,
                "fuente_TOC": "JSON"
            })

        # Sección 4: Información nutricional
        nutrition_text = "\n".join(f"{k}: {v}" for k, v in nutrition_facts.items())
        all_toc.append({
            "receta": title,
            "nivel": 1,
            "sección": "4",
            "título": "Información Nutricional",
            "texto": nutrition_text,
            "fuente_TOC": "JSON"
        })

        # Sección 5: Imagen (como URL)
        all_toc.append({
            "receta": title,
            "nivel": 1,
            "sección": "5",
            "título": "Imagen",
            "texto": img_url,
            "fuente_TOC": "JSON"
        })

# Convertir a DataFrame
df_toc_mejorado = pd.DataFrame(all_toc)
df_toc_mejorado
# Out:
#                  receta  nivel sección                   título  \
# 0    Rotisserie Chicken      1       1                  Resumen
# 1    Rotisserie Chicken      1       2             Ingredientes
# 2    Rotisserie Chicken      2     3.1                   Paso 1
# 3    Rotisserie Chicken      2     3.2                   Paso 2
# 4    Rotisserie Chicken      2     3.3                   Paso 3
# ..                  ...    ...     ...                      ...
# 163    Beer Can Chicken      2     3.3                   Paso 3
# 164    Beer Can Chicken      2     3.4                   Paso 4
# 165    Beer Can Chicken      2     3.5                   Paso 5
# 166    Beer Can Chicken      1       4  Información Nutricional
# 167    Beer Can Chicken      1       5                   Imagen
#
#                                                  texto fuente_TOC
# 0    This rotisserie chicken recipe is so easy to m...       JSON
# 1    - 1 (3 pound) whole chicken\n- 1 pinch salt\n-...       JSON
# 2    Gather all ingredients. Preheat an outdoor gri...       JSON
# 3    Season chicken cavity with a pinch of salt. Ti...       JSON
# 4    Place rotisserie over the preheated grill and ...       JSON
# ..                                                 ...        ...
# 163  Rinse chicken under cold running water. Discar...       JSON
# 164  Place chicken, standing on the can, directly o...       JSON
# 165  Remove chicken from the grill and discard beer...       JSON
# 166  Calories: 546\nFat: 27g\nCarbs: 24g\nProtein: 48g       JSON
# 167  https://www.allrecipes.com/thmb/h5gxnvsK99uVQ_...       JSON
#
# [168 rows x 6 columns]

# %%
def normalize_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Convertir a minúsculas
    text = re.sub(r'\s+', ' ', text)  # Reemplazar múltiples espacios por uno
    text = re.sub(r'[^\w\s]', '', text)  # Eliminar puntuación y caracteres especiales
    return text.strip()
df_toc_mejorado['texto_normalizado'] = df_toc_mejorado['texto'].apply(normalize_text)
df_toc_mejorado
# Out:
#                  receta  nivel sección                   título  \
# 0    Rotisserie Chicken      1       1                  Resumen
# 1    Rotisserie Chicken      1       2             Ingredientes
# 2    Rotisserie Chicken      2     3.1                   Paso 1
# 3    Rotisserie Chicken      2     3.2                   Paso 2
# 4    Rotisserie Chicken      2     3.3                   Paso 3
# ..                  ...    ...     ...                      ...
# 163    Beer Can Chicken      2     3.3                   Paso 3
# 164    Beer Can Chicken      2     3.4                   Paso 4
# 165    Beer Can Chicken      2     3.5                   Paso 5
# 166    Beer Can Chicken      1       4  Información Nutricional
# 167    Beer Can Chicken      1       5                   Imagen
#
#                                                  texto fuente_TOC  \
# 0    This rotisserie chicken recipe is so easy to m...       JSON
# 1    - 1 (3 pound) whole chicken\n- 1 pinch salt\n-...       JSON
# 2    Gather all ingredients. Preheat an outdoor gri...       JSON
# 3    Season chicken cavity with a pinch of salt. Ti...       JSON
# 4    Place rotisserie over the preheated grill and ...       JSON
# ..                                                 ...        ...
# 163  Rinse chicken under cold running water. Discar...       JSON
# 164  Place chicken, standing on the can, directly o...       JSON
# 165  Remove chicken from the grill and discard beer...       JSON
# 166  Calories: 546\nFat: 27g\nCarbs: 24g\nProtein: 48g       JSON
# 167  https://www.allrecipes.com/thmb/h5gxnvsK99uVQ_...       JSON
#
#                                      texto_normalizado
# 0    this rotisserie chicken recipe is so easy to m...
# 1    1 3 pound whole chicken  1 pinch salt  ¼ cup b...
# 2    gather all ingredients preheat an outdoor gril...
# 3    season chicken cavity with a pinch of salt tie...
# 4    place rotisserie over the preheated grill and ...
# ..                                                 ...
# 163  rinse chicken under cold running water discard...
# 164  place chicken standing on the can directly on ...
# 165  remove chicken from the grill and discard beer...
# 166         calories 546 fat 27g carbs 24g protein 48g
# 167  httpswwwallrecipescomthmbh5gxnvsk99uvq_aeppp1m...
#
# [168 rows x 7 columns]

# %%
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# Aplicar al DataFrame de TOC
df_toc_mejorado['texto_filtrado'] = df_toc_mejorado['texto_normalizado'].apply(remove_stopwords)
df_toc_mejorado
# Out:
#                  receta  nivel sección                   título  \
# 0    Rotisserie Chicken      1       1                  Resumen
# 1    Rotisserie Chicken      1       2             Ingredientes
# 2    Rotisserie Chicken      2     3.1                   Paso 1
# 3    Rotisserie Chicken      2     3.2                   Paso 2
# 4    Rotisserie Chicken      2     3.3                   Paso 3
# ..                  ...    ...     ...                      ...
# 163    Beer Can Chicken      2     3.3                   Paso 3
# 164    Beer Can Chicken      2     3.4                   Paso 4
# 165    Beer Can Chicken      2     3.5                   Paso 5
# 166    Beer Can Chicken      1       4  Información Nutricional
# 167    Beer Can Chicken      1       5                   Imagen
#
#                                                  texto fuente_TOC  \
# 0    This rotisserie chicken recipe is so easy to m...       JSON
# 1    - 1 (3 pound) whole chicken\n- 1 pinch salt\n-...       JSON
# 2    Gather all ingredients. Preheat an outdoor gri...       JSON
# 3    Season chicken cavity with a pinch of salt. Ti...       JSON
# 4    Place rotisserie over the preheated grill and ...       JSON
# ..                                                 ...        ...
# 163  Rinse chicken under cold running water. Discar...       JSON
# 164  Place chicken, standing on the can, directly o...       JSON
# 165  Remove chicken from the grill and discard beer...       JSON
# 166  Calories: 546\nFat: 27g\nCarbs: 24g\nProtein: 48g       JSON
# 167  https://www.allrecipes.com/thmb/h5gxnvsK99uVQ_...       JSON
#
#                                      texto_normalizado  \
# 0    this rotisserie chicken recipe is so easy to m...
# 1    1 3 pound whole chicken  1 pinch salt  ¼ cup b...
# 2    gather all ingredients preheat an outdoor gril...
# 3    season chicken cavity with a pinch of salt tie...
# 4    place rotisserie over the preheated grill and ...
# ..                                                 ...
# 163  rinse chicken under cold running water discard...
# 164  place chicken standing on the can directly on ...
# 165  remove chicken from the grill and discard beer...
# 166         calories 546 fat 27g carbs 24g protein 48g
# 167  httpswwwallrecipescomthmbh5gxnvsk99uvq_aeppp1m...
#
#                                         texto_filtrado
# 0    rotisserie chicken recipe easy make simple sea...
# 1    1 3 pound whole chicken 1 pinch salt ¼ cup but...
# 2    gather ingredients preheat outdoor grill high ...
# 3    season chicken cavity pinch salt tie legs toge...
# 4    place rotisserie preheated grill cook 10 minut...
# ..                                                 ...
# 163  rinse chicken cold running water discard gible...
# 164  place chicken standing directly preheated gril...
# 165  remove chicken grill discard beer cover chicke...
# 166         calories 546 fat 27g carbs 24g protein 48g
# 167  httpswwwallrecipescomthmbh5gxnvsk99uvq_aeppp1m...
#
# [168 rows x 8 columns]

# %% [markdown]
# ## Parte 3: Cálculo de Embeddings e Indexación en base de datos vectorial
#
# Aquí, una vez que se ha calculado el embedding de cada documento, se deberá indexar este embedding en una base de datos vectorial como FAISS, ChromaDB o Pinecone

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
#generar funcion embeddings para todo el texto
def generate_embeddings(text):
    return model.encode(text)
# Aplicar la función de embeddings al DataFrame
df_toc_mejorado['embeddings'] = df_toc_mejorado['texto_normalizado'].apply(generate_embeddings)
df_toc_mejorado
# Out:
#                  receta  nivel sección                   título  \
# 0    Rotisserie Chicken      1       1                  Resumen
# 1    Rotisserie Chicken      1       2             Ingredientes
# 2    Rotisserie Chicken      2     3.1                   Paso 1
# 3    Rotisserie Chicken      2     3.2                   Paso 2
# 4    Rotisserie Chicken      2     3.3                   Paso 3
# ..                  ...    ...     ...                      ...
# 163    Beer Can Chicken      2     3.3                   Paso 3
# 164    Beer Can Chicken      2     3.4                   Paso 4
# 165    Beer Can Chicken      2     3.5                   Paso 5
# 166    Beer Can Chicken      1       4  Información Nutricional
# 167    Beer Can Chicken      1       5                   Imagen
#
#                                                  texto fuente_TOC  \
# 0    This rotisserie chicken recipe is so easy to m...       JSON
# 1    - 1 (3 pound) whole chicken\n- 1 pinch salt\n-...       JSON
# 2    Gather all ingredients. Preheat an outdoor gri...       JSON
# 3    Season chicken cavity with a pinch of salt. Ti...       JSON
# 4    Place rotisserie over the preheated grill and ...       JSON
# ..                                                 ...        ...
# 163  Rinse chicken under cold running water. Discar...       JSON
# 164  Place chicken, standing on the can, directly o...       JSON
# 165  Remove chicken from the grill and discard beer...       JSON
# 166  Calories: 546\nFat: 27g\nCarbs: 24g\nProtein: 48g       JSON
# 167  https://www.allrecipes.com/thmb/h5gxnvsK99uVQ_...       JSON
#
#                                      texto_normalizado  \
# 0    this rotisserie chicken recipe is so easy to m...
# 1    1 3 pound whole chicken  1 pinch salt  ¼ cup b...
# 2    gather all ingredients preheat an outdoor gril...
# 3    season chicken cavity with a pinch of salt tie...
# 4    place rotisserie over the preheated grill and ...
# ..                                                 ...
# 163  rinse chicken under cold running water discard...
# 164  place chicken standing on the can directly on ...
# 165  remove chicken from the grill and discard beer...
# 166         calories 546 fat 27g carbs 24g protein 48g
# 167  httpswwwallrecipescomthmbh5gxnvsk99uvq_aeppp1m...
#
#                                         texto_filtrado  \
# 0    rotisserie chicken recipe easy make simple sea...
# 1    1 3 pound whole chicken 1 pinch salt ¼ cup but...
# 2    gather ingredients preheat outdoor grill high ...
# 3    season chicken cavity pinch salt tie legs toge...
# 4    place rotisserie preheated grill cook 10 minut...
# ..                                                 ...
# 163  rinse chicken cold running water discard gible...
# 164  place chicken standing directly preheated gril...
# 165  remove chicken grill discard beer cover chicke...
# 166         calories 546 fat 27g carbs 24g protein 48g
# 167  httpswwwallrecipescomthmbh5gxnvsk99uvq_aeppp1m...
#
#                                             embeddings
# 0    [-0.023811527, -0.059269447, -0.014561937, -0....
# 1    [-0.048987847, -0.042561907, 0.020795476, 0.04...
# 2    [-0.012102308, -0.0099021215, 0.028517244, 0.0...
# 3    [0.021088272, 0.0021674812, 0.0018654675, 0.00...
# 4    [0.046412326, 0.01917596, -0.016095642, 0.0264...
# ..                                                 ...
# 163  [-0.03429031, -0.05328498, 0.011423018, -0.047...
# 164  [-0.015713332, 0.007325911, -0.09648346, 0.004...
# 165  [-0.032796048, 0.053265978, -0.020818694, 0.06...
# 166  [-0.004715458, -0.00885202, -0.0130152395, 0.0...
# 167  [0.014733993, 0.028662264, -0.050850052, -0.08...
#
# [168 rows x 9 columns]

# %%
#sacar los embeddings del df
embeddings = np.array(df_toc_mejorado['embeddings'].tolist())
embeddings
# Out:
# array([[-0.02381153, -0.05926945, -0.01456194, ...,  0.05301848,
#          0.00985585,  0.0397049 ],
#        [-0.04898785, -0.04256191,  0.02079548, ...,  0.0187341 ,
#         -0.08399854,  0.07460677],
#        [-0.01210231, -0.00990212,  0.02851724, ...,  0.02661788,
#         -0.08309534, -0.04186901],
#        ...,
#        [-0.03279605,  0.05326598, -0.02081869, ...,  0.01544208,
#         -0.04566492,  0.04807663],
#        [-0.00471546, -0.00885202, -0.01301524, ..., -0.04609126,
#          0.00216587, -0.06349945],
#        [ 0.01473399,  0.02866226, -0.05085005, ...,  0.06327105,
#          0.05968732,  0.00757135]], shape=(168, 384), dtype=float32)

# %%
# Crear un índice FAISS para búsqueda de similitud
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# %% [markdown]
# ## Parte 4: Búsqueda y obtención del contexto
#
# En esta parte debemos definir una _query_ y buscar los documentos que más se relacionan con ella.
#
# Estos documentos formarán el contexto que vamos a entregar al LLM.

# %%
# Solicitar input del usuario
query = input("Ingrese su consulta: ").lower()

# %%
print("Consulta ingresada:", query)
query_embedding = model.encode(query)
query_embedding
# Out:
# Consulta ingresada: chicken
# array([-4.19756435e-02, -1.32821109e-02, -3.84519994e-02,  4.70161363e-02,
#        -4.22213897e-02,  9.95706953e-03,  1.65552616e-01, -8.08368064e-03,
#         7.46925622e-02, -4.19138111e-02, -1.35424052e-04, -4.13294770e-02,
#        -2.45801006e-02, -2.45018415e-02, -2.68594064e-02, -6.07909635e-02,
#         5.55869006e-02, -6.74602240e-02, -3.80850062e-02, -9.65465009e-02,
#        -1.52622491e-01,  2.72846804e-03,  4.57986593e-02,  1.00333965e-03,
#        -3.66761684e-02,  6.42383918e-02,  2.05617640e-02,  3.25725265e-02,
#        -2.97653694e-02, -8.06936324e-02,  3.97887193e-02, -9.64505598e-03,
#        -2.50394951e-04, -2.05167476e-03, -4.87854332e-02, -1.74947008e-02,
#         3.42604076e-03, -4.67465855e-02,  7.17530549e-02,  6.85145427e-03,
#         1.77733358e-02, -8.47468451e-02,  6.91125318e-02, -4.46848050e-02,
#         4.89137694e-02,  4.59626056e-02,  1.33782895e-02,  5.71032278e-02,
#         5.12409657e-02, -3.11464556e-02, -3.81297953e-02, -2.83781253e-02,
#        -7.45173544e-02,  4.83146012e-02,  3.65505293e-02,  1.05488345e-01,
#        -8.65619034e-02, -3.08297947e-02, -8.44484046e-02, -3.34524326e-02,
#        -3.34431566e-02,  1.15222447e-02, -1.02109765e-03,  4.53188755e-02,
#        -2.27686437e-03, -4.86774743e-02, -6.18120842e-03,  6.67834580e-02,
#        -8.51964229e-04,  7.31748343e-03,  2.05127969e-02, -1.39501253e-02,
#        -1.14512891e-02,  8.93086046e-02, -2.13181283e-02,  2.39037661e-04,
#         6.88562542e-02, -3.52003239e-02,  1.01798989e-01, -1.99557673e-02,
#        -2.97187790e-02, -5.31852581e-02, -8.71230364e-02,  3.65564674e-02,
#        -2.46904697e-02, -1.96079761e-02,  9.02896747e-03,  3.67421843e-03,
#        -5.25939725e-02, -1.85718737e-03,  2.97688544e-02, -1.07907811e-02,
#         2.15670485e-02,  4.45865504e-02, -2.06830818e-02,  5.92286400e-02,
#         1.62552707e-02, -1.01144753e-01, -6.33084476e-02,  1.90248504e-01,
#        -2.23533232e-02,  3.79685163e-02, -5.34835737e-04, -4.85420860e-02,
#         2.47989148e-02,  5.38106635e-03, -2.41030310e-03,  5.28986892e-03,
#         3.23265940e-02, -9.97555908e-03, -8.94706920e-02,  3.77703346e-02,
#        -4.31339182e-02, -3.30361649e-02, -2.19291840e-02, -6.01893850e-03,
#         2.98422650e-02, -5.73032126e-02, -4.92697954e-02,  3.79441641e-02,
#        -1.87885482e-02,  1.02510983e-02,  8.43561441e-03,  2.59730909e-02,
#        -4.92720641e-02,  4.45576763e-04, -6.20731153e-02, -3.88900404e-33,
#        -6.70420006e-03, -9.26251188e-02,  1.00073226e-01, -1.43903485e-02,
#         6.39919192e-02,  3.14164050e-02,  3.12869474e-02, -4.99751754e-02,
#        -1.02452040e-02,  5.58535457e-02, -2.32003909e-02, -4.89106886e-02,
#        -5.61568886e-02, -1.41449180e-02,  1.43611684e-01,  1.61664747e-02,
#        -5.03706373e-03,  4.00848128e-02, -8.99861008e-03, -2.51341704e-02,
#        -5.65020479e-02,  1.19071819e-01,  6.58476725e-02,  6.17069341e-02,
#         1.68617629e-02, -1.29285023e-01, -1.17964493e-02, -7.47042075e-02,
#        -7.15057366e-03,  1.75503585e-02,  1.90311875e-02,  4.96940687e-02,
#        -3.09375320e-02, -3.46119404e-02, -4.51906696e-02, -8.08040723e-02,
#         3.44998278e-02, -9.63759720e-02,  1.58680584e-02,  6.66207224e-02,
#         6.60661608e-02, -6.58667758e-02,  1.37010803e-02,  6.53675124e-02,
#        -2.31306143e-02, -2.26814952e-02,  5.41624576e-02,  2.03854349e-02,
#        -8.54476243e-02,  1.77268554e-02,  3.70062329e-02, -5.68684600e-02,
#         1.39468564e-02, -3.06905434e-02,  5.14124148e-03, -6.66763112e-02,
#         4.09583226e-02,  1.78204812e-02, -3.33846104e-03,  1.37466425e-02,
#        -8.86216909e-02,  6.16776347e-02,  8.30865186e-03,  7.84990750e-03,
#         3.33187357e-02, -7.28124082e-02, -5.73986843e-02, -4.78945673e-02,
#         1.15357116e-02,  2.42887326e-02,  6.28966242e-02, -5.85769936e-02,
#         8.46507102e-02, -7.83052593e-02,  3.66799161e-02,  4.38275822e-02,
#        -5.76585382e-02,  3.41053233e-02,  5.47822267e-02, -2.76496224e-02,
#         1.39758550e-02,  6.91423714e-02,  3.52606876e-04,  8.12785253e-02,
#        -1.84380598e-02,  1.11839049e-01, -5.43224700e-02, -8.24228302e-02,
#         1.12061881e-01, -1.89737901e-02, -2.38781124e-02, -8.98251217e-03,
#         8.83123055e-02, -7.19249770e-02, -6.75119981e-02,  3.84664731e-33,
#        -8.25095996e-02, -1.99167356e-02, -7.61546493e-02,  1.45565495e-01,
#         3.28090750e-02, -7.81232789e-02,  1.02846464e-02,  1.94572471e-02,
#         3.69704291e-02, -2.15061083e-02, -4.39810008e-02, -5.64517006e-02,
#         3.62578332e-02, -1.96332354e-02,  2.27657929e-02,  6.89513385e-02,
#         5.16929366e-02,  3.04890405e-02,  2.59393491e-02,  1.48470430e-02,
#        -5.50221391e-02, -9.18508619e-02,  1.47695513e-02,  2.72067506e-02,
#        -1.02783628e-02,  7.13963211e-02,  3.69772576e-02,  6.52020201e-02,
#        -2.74680965e-02, -5.53779118e-02,  1.17548332e-02, -5.01937270e-02,
#         2.76440252e-02, -3.64718847e-02,  5.79437613e-03,  1.06860057e-01,
#         1.10064559e-01, -5.12538701e-02,  6.19144877e-03, -2.40084659e-02,
#         7.10238665e-02,  2.48052627e-02,  2.42214445e-02,  1.48066297e-01,
#         5.10482723e-03, -1.26414141e-02, -2.64023487e-02, -6.20514806e-03,
#         1.85400248e-02,  2.76945103e-02, -6.99140653e-02, -7.61438310e-02,
#         5.14481813e-02, -2.80542709e-02,  2.03290675e-02, -1.13508478e-02,
#        -7.33161643e-02,  3.15201394e-02,  3.49556543e-02,  3.97328734e-02,
#         1.36728082e-02,  6.78862855e-02,  1.93141922e-02,  6.36090115e-02,
#         4.49653342e-02,  4.35281396e-02, -4.07687910e-02, -9.50309820e-03,
#         3.09572015e-02, -4.13629785e-02,  4.58910223e-03,  4.55238968e-02,
#         1.38498435e-03,  3.46073397e-02, -6.17940836e-02,  3.94916087e-02,
#        -3.35370563e-02,  1.60063095e-02,  3.71376760e-02,  1.42725296e-02,
#        -2.03025434e-03, -1.09642923e-01, -6.39854223e-02, -1.11776944e-02,
#        -3.27648930e-02, -2.14863960e-02,  1.28023159e-02,  9.62839425e-02,
#         3.43875363e-02, -3.93542042e-03,  8.04871321e-03, -1.94751881e-02,
#        -6.46183779e-03,  3.89292687e-02, -1.76646840e-02, -1.16194387e-08,
#         7.56308995e-03, -6.63758218e-02, -2.65228078e-02,  3.79545689e-02,
#         1.24849096e-01, -1.92938827e-03, -2.72441339e-02, -4.32117432e-02,
#         1.14002541e-01,  2.89724451e-02, -3.01217716e-02,  1.96563695e-02,
#         6.61743134e-02,  3.32595184e-02, -6.46015210e-03,  1.27904927e-02,
#         2.38466505e-02, -3.63020189e-02, -1.45491390e-02,  4.06220928e-02,
#        -1.46427786e-03,  6.41868860e-02, -2.39262432e-02,  6.89584948e-03,
#         3.06828991e-02, -6.39015585e-02, -5.22755226e-03,  1.20644145e-01,
#         3.69507447e-02,  1.57669522e-02, -4.23237905e-02,  2.50000274e-03,
#        -4.90809716e-02,  1.65594015e-02,  1.70744453e-02, -8.86039957e-02,
#         1.55919986e-02, -3.23063806e-02,  3.74841318e-02, -3.65807973e-02,
#        -7.33003393e-03,  4.53815497e-02,  3.64832557e-03, -7.26380050e-02,
#        -4.52942215e-02, -4.47489507e-02, -5.74088395e-02, -2.98425239e-02,
#        -7.83183277e-02, -5.41303642e-02,  3.34292427e-02,  1.46944299e-02,
#         6.32985011e-02,  6.88213632e-02,  2.51098722e-02, -4.96630650e-03,
#         2.54583173e-02,  4.74605560e-02, -1.85193848e-02,  3.97696011e-02,
#         2.99419314e-02,  5.52991256e-02,  3.17040784e-03,  6.26145750e-02],
#       dtype=float32)

# %%
# Realizar la búsqueda de similitud
k = 5  # Número de resultados a recuperar
D, I = index.search(np.array([query_embedding]), k)  # D: distancias, I: índices
#guardar en top_k_indices los índices de los k resultados más cercanos
top_k_indices = I[0]
top_k_indices
# Out:
# array([98, 83, 80,  3, 13])

# %%
# Mostrar los resultados de búsqueda semántica
for i, idx in enumerate(I[0]):
    fila = df_toc_mejorado.iloc[idx]
    print(f"Resultado {i + 1}:")
    print(f"Receta: {fila['receta']}")
    print(f"Sección: {fila['sección']} - {fila['título']}")
    print(f"Texto: {fila['texto_filtrado'][:200]}...")  # Solo primeros 200 caracteres
    print(f"Distancia: {D[0][i]:.4f}")
    print("-" * 50)
# Out:
# Resultado 1:
# Receta: The Best Beer Can Chicken Ever
# Sección: 1 - Resumen
# Texto: spicy skin tender roast chicken...
# Distancia: 0.9180
# --------------------------------------------------
# Resultado 2:
# Receta: Rosemary Buttermilk Chicken
# Sección: 1 - Resumen
# Texto: summertime chickengrilling favorite family find making week week...
# Distancia: 0.9242
# --------------------------------------------------
# Resultado 3:
# Receta: Miso Honey Chicken
# Sección: 3.7 - Paso 7
# Texto: plate chicken alongside lemon wedges sprinkled cayenne pepper squeeze spicy lemon chicken cut...
# Distancia: 0.9309
# --------------------------------------------------
# Resultado 4:
# Receta: Rotisserie Chicken
# Sección: 3.2 - Paso 2
# Texto: season chicken cavity pinch salt tie legs together kitchen string tie wings bird secure chicken rotisserie attachment dotdash meredith food studios...
# Distancia: 0.9684
# --------------------------------------------------
# Resultado 5:
# Receta: Rotisserie Chicken
# Sección: 3.2 - Paso 2
# Texto: season chicken cavity pinch salt tie legs together kitchen string tie wings bird secure chicken rotisserie attachment dotdash meredith food studios...
# Distancia: 0.9684
# --------------------------------------------------

# %%
# Agrupar fragmentos por receta (usamos los top 3 más similares)
recetas_encontradas = df_toc_mejorado.iloc[top_k_indices[:3]]['receta'].unique()

# Extraer toda la información de esas recetas
context = ""
for receta in recetas_encontradas:
    partes = df_toc_mejorado[df_toc_mejorado['receta'] == receta]
    context += f"\n\nReceta: {receta}\n"
    for _, fila in partes.iterrows():
        context += f"\n{fila['título']}:\n{fila['texto']}\n"

context
# Out:
# "\n\nReceta: The Best Beer Can Chicken Ever\n\nResumen:\nSpicy skin and tender roast chicken!\n\nIngredientes:\n- 1 cup chocolate stout beer\n- 3  green Thai chile peppers\n- 3 cloves garlic, peeled\n- 3 tablespoons brown sugar\n- 2 teaspoons dry mustard\n- 1 teaspoon garam masala\n- 1 teaspoon kosher salt\n- 1 teaspoon ground black pepper\n- ½ teaspoon cayenne pepper\n- ½ teaspoon ground cumin\n- ½ teaspoon ground cinnamon\n- ½ teaspoon onion powder\n- ½ teaspoon garlic powder\n- ¼ teaspoon ground nutmeg\n- 1 (5 pound) whole chicken\n\nPaso 1:\nPreheat grill for medium heat. If using charcoal, push coals to the side of the grilling area for indirect heat.\n\nPaso 2:\nPour stout beer into an empty 12-ounce soda can and drop Thai chilies and garlic cloves into the can. Mix brown sugar, dry mustard, garam masala, kosher salt, black pepper, cayenne pepper, cumin, cinnamon, onion powder, garlic powder, and nutmeg in a bowl.\n\nPaso 3:\nRinse the chicken and coat the skin with the entire batch of spice rub. Place soda can containing beer mixture onto the prepared grill and sit the chicken upright onto the can.\n\nPaso 4:\nGrill chicken over indirect heat until juices run clear and an instant-read meat thermometer inserted into the thickest part of the breast, not touching bone, reads at least 165 degrees F (75 degrees C), about 45 minutes. Let chicken rest 10 minutes before serving.\n\nInformación Nutricional:\nCalories: 532\nFat: 29g\nCarbs: 10g\nProtein: 52g\n\nImagen:\nNone\n\n\nReceta: Rosemary Buttermilk Chicken\n\nResumen:\nA summertime chicken-grilling favorite of my family that I find myself making week after week.\n\nIngredientes:\n- 2 ½ cups buttermilk\n- 15 cloves garlic, minced\n- 1 tablespoon smoked paprika\n- kosher salt and ground black pepper to taste\n- 8 sprigs fresh rosemary\n- 1 (3 to 3 1/2 pound) whole chicken, quartered\n\nPaso 1:\nMix buttermilk, garlic, paprika, salt, and pepper together in a large bowl; stir to combine.\n\nPaso 2:\nMassage rosemary sprigs to release fragrant oils. Put rosemary in a large resealable plastic bag; pour in buttermilk mixture. Add chicken parts to the bag, seal carefully, and place in refrigerator. Marinate, turning the bag occasionally, 4 hours to overnight.\n\nPaso 3:\nPreheat grill for medium heat and lightly oil the grate.\n\nPaso 4:\nTransfer chicken to a plate; discard marinade. Grill chicken until no longer pink at the bone and the juices run clear, turning a few times, 20 to 30 minutes. An instant-read thermometer inserted near the bone should read 165 degrees F (74 degrees C).\n\nInformación Nutricional:\nCalories: 336\nFat: 17g\nCarbs: 8g\nProtein: 36g\n\nImagen:\nNone\n\n\nReceta: Miso Honey Chicken\n\nResumen:\nIt's not hard to make a great marinade with just a few ingredients, as long as one of those ingredients is the magical miso. This super savory paste, made from fermented rice, barley, and soybeans, isn't that hard to find. While the marinade is simple, the flavors are anything but in this miso chicken.\n\nIngredientes:\n- 3 tablespoons white miso\n- 2 tablespoons honey\n- ¼ cup rice vinegar\n- 2 teaspoons hot sauce\n- 1 tablespoon kosher salt\n- 1  whole chicken, halved, wing tips separated\n- kosher salt to taste\n- ½  lemon, cut into wedges, or to taste\n- 1 pinch cayenne pepper\n\nPaso 1:\nCombine miso and honey in a bowl. Pour in rice vinegar, followed by hot sauce and 1 tablespoon salt. Whisk well until mostly smooth.\n\nPaso 2:\nCut 3 to 4 slashes into legs and thighs of chicken halves. Toss chicken in the marinade until well coated. Refrigerate for 2 to 12 hours.\n\nPaso 3:\nFlip chicken over in the bowl. Sprinkle more kosher salt on top.\n\nPaso 4:\nPreheat a grill to 350 degrees F (175 degrees C) over indirect heat.\n\nPaso 5:\nPlace chicken on the grill and cover. Grill for 20 minutes and flip chicken over. Cover and grill for another 20 minutes.\n\nPaso 6:\nBrush the excess marinade on top of chicken. Cover again and continue cooking until an instan ...

# %% [markdown]
# ## Parte 5: Generación de Respuesta
#
# Aquí, entregamos el contexto al LLM, y él nos responde a la _query_ con una explicación en lenguaje natural.

# %%
prompt = f"""Eres una aplicación de Recuperación Aumentada con Generación (RAG) que responde siempre en español. A continuación se te proporciona información de recetas. Tu tarea es:
1. Identificar cuál receta es más relevante para la solicitud del usuario.
2. Generar la **receta completa** con un formato de presentación limpio, humano y legible.
IMPORTANTE: 
No devuelvas la receta en formato JSON ni en bloque de código. Preséntala como una receta común, organizada por secciones, así:

Título: ...
Calificación: ...
Tiempo total: ...
Porciones: ...

Ingredientes:
- ingrediente 1
- ingrediente 2

Pasos:
1. Paso uno
2. Paso dos

Información nutricional:
- Calorías: ...
- Grasas: ...
- Proteínas: ...

Si no puedes generar la receta, responde: "No tengo suficiente información para generar esa receta."

Contexto:
{context}

Pregunta:
Genera la receta completa relacionada con: {query}
"""

# %%
#aqui api key de openai

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

# Guardar el resultado
respuesta = completion.choices[0].message.content

# Limpiar bloque Markdown si es necesario
import re
respuesta_limpia = re.sub(r"^```[a-z]*|```$", "", respuesta.strip(), flags=re.MULTILINE)

print("Receta generada:\n")
print(respuesta_limpia)
# Out:
# Receta generada:
#
# Título: Pollo Miso y Miel
#
# Calificación: ★★★★☆
#
# Tiempo total: 2 a 12 horas (incluyendo marinado) + 40 minutos de cocción
#
# Porciones: 4
#
# Ingredientes:
# - 3 cucharadas de miso blanco
# - 2 cucharadas de miel
# - ¼ de taza de vinagre de arroz
# - 2 cucharaditas de salsa picante
# - 1 cucharada de sal kosher
# - 1 pollo entero, cortado por la mitad, con puntas de alas separadas
# - Sal kosher al gusto
# - ½ limón, cortado en cuñas, o al gusto
# - 1 pizca de cayena
#
# Pasos:
# 1. En un bol, combina el miso y la miel. Agrega el vinagre de arroz, seguido de la salsa picante y 1 cucharada de sal. Mezcla bien hasta obtener una consistencia mayormente suave.
#
# 2. Haz 3 a 4 cortes en las piernas y los muslos de las mitades del pollo. Mezcla el pollo en el adobo hasta que esté bien cubierto. Refrigera durante 2 a 12 horas.
#
# 3. Gira el pollo en el bol. Espolvorea más sal kosher por encima.
#
# 4. Precalienta una parrilla a 175 grados C (350 grados F) a fuego indirecto.
#
# 5. Coloca el pollo en la parrilla y cierra la tapa. Asa durante 20 minutos, luego voltea el pollo. Cubre y asa durante otros 20 minutos.
#
# 6. Pincela el exceso de adobo sobre el pollo. Cierra nuevamente la tapa y continúa cocinando hasta que un termómetro de lectura instantánea insertado en el centro de cada muslo indique 74 grados C (165 grados F), de 5 a 10 minutos más.
#
# 7. Sirve el pollo acompañado de cuñas de limón esparcidas con cayena. Exprime un poco de limón picante sobre el pollo al cortarlo.
#
# Información nutricional:
# - Calorías: 255
# - Grasas: 13 g
# - Carbohidratos: 7 g
# - Proteínas: 27 g
